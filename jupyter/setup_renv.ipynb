# %%
library(renv)
renv::activate()
renv::install("FFTrees")
renv::install("data.table")
renv::install("rlang")
renv::install("vctrs")
renv::install("rsample")
renv::install("h2o")
renv::install("data.table")
renv::install("ggplot2")
renv::install("bit64")
renv::install("dygraphs")


renv::settings$snapshot.type("all")
renv::snapshot()
# Out:
# Installing FFTrees [1.9.0] ...
# 	OK [linked cache]
# Installing data.table [1.14.8] ...
# 	OK [linked cache]
# Installing rlang [1.1.0] ...
# 	OK [linked cache]
# Installing vctrs [0.6.1] ...
# 	OK [linked cache]
# Installing rsample [1.1.1] ...
# 	OK [linked cache]
# Installing h2o [3.40.0.1] ...
# 	OK [linked cache]
# Installing data.table [1.14.8] ...
# 	OK [linked cache]
# Installing ggplot2 [3.4.2] ...
# 	OK [linked cache]
# Installing bit64 [4.0.5] ...
# 	OK [linked cache]
# Retrieving 'https://cloud.r-project.org/src/contrib/htmlwidgets_1.6.2.tar.gz' ...
# 	OK [downloaded 847.1 Kb in 2.4 secs]
# Retrieving 'https://cloud.r-project.org/src/contrib/rmarkdown_2.21.tar.gz' ...
# 	OK [downloaded 2 Mb in 0.2 secs]
# Retrieving 'https://cloud.r-project.org/src/contrib/sass_0.4.5.tar.gz' ...
# 	OK [downloaded 2.9 Mb in 0.3 secs]
# Retrieving 'https://cloud.r-project.org/src/contrib/cachem_1.0.7.tar.gz' ...
# 	OK [downloaded 25.6 Kb in 0.1 secs]
# ...
